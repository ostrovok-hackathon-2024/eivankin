# %% [markdown]
# # 3. Modeling
#
# `from sklearn.models import sdelat_horoscho`

# %% [markdown]
# Сначала загрузим итоговый датасет:

# %%
from pathlib import Path

import pandas as pd

SEED = 42
DATA_DIR = Path("../preprocessed_data")

df = pd.read_csv(DATA_DIR / "augmented_merged.csv")

# %%
target_names = [col for col in df.columns if col != "rate_name"]
target_names
# Out:
# ['class',
#  'quality',
#  'bathroom',
#  'bedding',
#  'capacity',
#  'club',
#  'balcony',
#  'view']

# %% [markdown]
# Разобъём датасет на обучающую и тестовую выборки:

# %%
from sklearn.model_selection import train_test_split


def split_data(
    df_to_split: pd.DataFrame, target_name: str, test_size=0.2, random_state=SEED
):
    X = df_to_split["rate_name"]
    y = df_to_split[target_name]

    return train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )

# %% [markdown]
# Сделаем sklearn pipeline для векторизации и классификации:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score, classification_report


def get_pipeline(classifier):
    return Pipeline(
        [
            (
                "tfidf",
                TfidfVectorizer(
                    min_df=2,
                    sublinear_tf=True,
                    stop_words="english",
                ),
            ),
            ("clf", classifier),
        ]
    )


def train_classifier(classifier, X_train, y_train):
    pipeline = get_pipeline(classifier)
    return pipeline.fit(X_train, y_train)


def evaluate_pipeline(pipeline, X_test, y_test):
    y_pred = pipeline.predict(X_test)
    score = f1_score(y_test, y_pred, average="macro")
    print(f"Metrics report for {pipeline.steps[-1][1]} predicting {y_test.name}")
    print(f"F1 score: {score}")
    print(classification_report(y_test, y_pred, zero_division=0))
    print()
    return score

# %%
def get_dummy_classifier():
    return DummyClassifier(strategy="stratified", random_state=SEED)

def get_dummy_classifier_most_frequent():
    return DummyClassifier(strategy="most_frequent", random_state=SEED)

def get_nb_classifier():
    return ComplementNB()

def get_linear_classifier():
    return RidgeClassifier()

def get_linear_svc_classifier():
    return LinearSVC()

# %%
X_train, X_test, y_train, y_test = split_data(df, target_names[0])
pipe = train_classifier(get_dummy_classifier(), X_train, y_train)
print("Количество признаков:", len(pipe.steps[0][1].get_feature_names_out()))
# Out:
# Количество признаков: 3109

# %%
def check_one_classifier_on_one_target(classifier_getter, target_name, report_dict):
    X_train, X_test, y_train, y_test = split_data(df, target_name)
    pipe = train_classifier(classifier_getter(), X_train, y_train)
    score = evaluate_pipeline(pipe, X_test, y_test)
    report_dict[target_name] = score

def check_one_classifier(classifier_getter, report_dict):
    classifier_dict = {}
    for target_name in target_names:
        check_one_classifier_on_one_target(classifier_getter, target_name, classifier_dict)
    report_dict[str(classifier_getter())] = classifier_dict

# %% [markdown]
# Сравним простые модели на классификации н наших данных:

# %%
report = {}
for clf_getter in [get_dummy_classifier, get_dummy_classifier_most_frequent, get_nb_classifier, get_linear_classifier, get_linear_svc_classifier]:
    print("-" * 40)
    check_one_classifier(clf_getter, report)

report_df = pd.DataFrame(report)
report_df.head()
# Out:
# ----------------------------------------
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting class
# F1 score: 0.07164090903684332
#               precision    recall  f1-score   support
#
#    apartment       0.04      0.04      0.04       661
#     bungalow       0.01      0.01      0.01        68
#      camping       0.00      0.00      0.00         3
#      capsule       0.00      0.00      0.00        28
#       chalet       0.00      0.00      0.00        19
#      cottage       0.02      0.02      0.02        58
#         dorm       0.02      0.02      0.02       262
# junior-suite       0.02      0.02      0.02       399
#         room       0.76      0.76      0.76     11479
# run-of-house       0.00      0.00      0.00        11
#       studio       0.04      0.04      0.04       584
#        suite       0.08      0.08      0.08      1255
#         tent       0.00      0.00      0.00        10
#        villa       0.01      0.02      0.01       192
#
#     accuracy                           0.59     15029
#    macro avg       0.07      0.07      0.07     15029
# weighted avg       0.59      0.59      0.59     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting quality
# F1 score: 0.050187778171857975
#               precision    recall  f1-score   support
#
#   ambassador       0.00      0.00      0.00         4
#     business       0.00      0.00      0.00       127
#      classic       0.03      0.03      0.03       535
#      comfort       0.01      0.01      0.01       439
#       deluxe       0.13      0.13      0.13      1869
#      economy       0.02      0.02      0.02       438
#    executive       0.01      0.01      0.01       310
#        grand       0.02      0.01      0.01        73
#       luxury       0.01      0.01      0.01       127
#     platinum       0.00      0.00      0.00         4
#      premier       0.01      0.01      0.01       141
#      premium       0.02      0.02      0.02       346
# presidential       0.00      0.00      0.00        18
#     prestige       0.00      0.00      0.00        28
#    privilege       0.00      0.00      0.00        35
#        royal       0.00      0.00      0.00        31
#     standard       0.43      0.43      0.43      6442
#     superior       0.12      0.12      0.12      1609
#    undefined       0.15      0.15      0.15      2453
#
#     accuracy                           0.24     15029
#    macro avg       0.05      0.05      0.05     15029
# weighted avg       0.24      0.24      0.24     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting bathroom
# F1 score: 0.25180495779534917
#                            precision    recall  f1-score   support
#
# external private bathroom       0.00      0.00      0.00         3
#          private bathroom       0.97      0.97      0.97     14554
#           shared bathroom       0.04      0.04      0.04       461
#                 undefined       0.00      0.00      0.00        11
#
#                  accuracy                           0.94     15029
#                 macro avg       0.25      0.25      0.25     15029
#              weighted avg       0.94      0.94      0.94     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting bedding
# F1 score: 0.19874074133563252
#                        precision    recall  f1-score   support
#
#              bunk bed       0.00      0.00      0.00        58
# double/double-or-twin       0.62      0.62      0.62      9265
#              multiple       0.01      0.01      0.01       145
#            single bed       0.00      0.00      0.00       219
#             undefined       0.36      0.35      0.36      5342
#
#              accuracy                           0.51     15029
#             macro avg       0.20      0.20      0.20     15029
#          weighted avg       0.51      0.51      0.51     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting capacity
# F1 score: 0.14105653037676877
#               precision    recall  f1-score   support
#
#       double       0.62      0.62      0.62      9274
#    quadruple       0.04      0.04      0.04       582
#    quintuple       0.00      0.00      0.00         3
#     sextuple       0.00      0.00      0.00         2
#       single       0.07      0.07      0.07      1186
#       triple       0.01      0.01      0.01       373
#    undefined       0.25      0.24      0.24      3609
#
#     accuracy                           0.45     15029
#    macro avg       0.14      0.14      0.14     15029
# weighted avg       0.45      0.45      0.45     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting club
# F1 score: 0.5026728637396026
#               precision    recall  f1-score   support
#
#         club       0.01      0.01      0.01        93
#     not club       0.99      0.99      0.99     14936
#
#     accuracy                           0.99     15029
#    macro avg       0.50      0.50      0.50     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting balcony
# F1 score: 0.4958493968411889
#               precision    recall  f1-score   support
#
#      balcony       0.05      0.05      0.05       822
#   no balcony       0.94      0.95      0.95     14207
#
#     accuracy                           0.90     15029
#    macro avg       0.50      0.50      0.50     15029
# weighted avg       0.90      0.90      0.90     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='stratified') predicting view
# F1 score: 0.030407383354029018
#                     precision    recall  f1-score   support
#
#           bay view       0.00      0.00      0.00        36
#         beachfront       0.00      0.00      0.00        25
#     bosphorus view       0.00      0.00      0.00        13
#  burj-khalifa view       0.00      0.00      0.00        10
#         canal view       0.00      0.00      0.00        23
#          city view       0.04      0.04      0.04       633
#     courtyard view       0.00      0.00      0.00        56
#  dubai-marina view       0.00      0.00      0.00         2
#        garden view       0.02      0.02      0.02       382
#          golf view       0.00      0.00      0.00         6
#       harbour view       0.02      0.02      0.02        52
#        inland view       0.00      0.00      0.00        22
#       kremlin view       0.00      0.00      0.00         3
#          lake view       0.03      0.03      0.03        67
#          land view       0.00      0.00      0.00        75
#      mountain view       0.00      0.00      0.00       107
#        ocean front       0.00      0.00      0.00        36
#         ocean view       0.01      0.01      0.01       132
#     panoramic view       0.00      0.00      0.00        14
#          park view       0.00      0.00      0.00        47
#       partial view       0.00      0.00      0.00        17
# partial-ocean view       0.00      0.00      0.00        22
#   partial-sea view       0.02      0.02      0.02       161
#          pool view       0.01      0.01      0.01       196
#         river view       0.01      0.01      0.01        78
#          sea front       0.00      0.00      0.00        18
#           sea view       0.05      0.05      0.05       721
#  sheikh-zayed view       0.00      0.00      0.00         2
#        street view       0.00      0.00      0.00        20
#       sunrise view       0.00      0.00      0.00         3
#        sunset view       0.00      0.00      0.00        12
#          undefined       0.79      0.79      0.79     11850
#         water view       0.03      0.02      0.03        41
#          with view       0.01      0.01      0.01       147
#
#           accuracy                           0.63     15029
#          macro avg       0.03      0.03      0.03     15029
#       weighted avg       0.63      0.63      0.63     15029
#
#
# ----------------------------------------
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting class
# F1 score: 0.06186272607730281
#               precision    recall  f1-score   support
#
#    apartment       0.00      0.00      0.00       661
#     bungalow       0.00      0.00      0.00        68
#      camping       0.00      0.00      0.00         3
#      capsule       0.00      0.00      0.00        28
#       chalet       0.00      0.00      0.00        19
#      cottage       0.00      0.00      0.00        58
#         dorm       0.00      0.00      0.00       262
# junior-suite       0.00      0.00      0.00       399
#         room       0.76      1.00      0.87     11479
# run-of-house       0.00      0.00      0.00        11
#       studio       0.00      0.00      0.00       584
#        suite       0.00      0.00      0.00      1255
#         tent       0.00      0.00      0.00        10
#        villa       0.00      0.00      0.00       192
#
#     accuracy                           0.76     15029
#    macro avg       0.05      0.07      0.06     15029
# weighted avg       0.58      0.76      0.66     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting quality
# F1 score: 0.03158237916994527
#               precision    recall  f1-score   support
#
#   ambassador       0.00      0.00      0.00         4
#     business       0.00      0.00      0.00       127
#      classic       0.00      0.00      0.00       535
#      comfort       0.00      0.00      0.00       439
#       deluxe       0.00      0.00      0.00      1869
#      economy       0.00      0.00      0.00       438
#    executive       0.00      0.00      0.00       310
#        grand       0.00      0.00      0.00        73
#       luxury       0.00      0.00      0.00       127
#     platinum       0.00      0.00      0.00         4
#      premier       0.00      0.00      0.00       141
#      premium       0.00      0.00      0.00       346
# presidential       0.00      0.00      0.00        18
#     prestige       0.00      0.00      0.00        28
#    privilege       0.00      0.00      0.00        35
#        royal       0.00      0.00      0.00        31
#     standard       0.43      1.00      0.60      6442
#     superior       0.00      0.00      0.00      1609
#    undefined       0.00      0.00      0.00      2453
#
#     accuracy                           0.43     15029
#    macro avg       0.02      0.05      0.03     15029
# weighted avg       0.18      0.43      0.26     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting bathroom
# F1 score: 0.2459858702633269
#                            precision    recall  f1-score   support
#
# external private bathroom       0.00      0.00      0.00         3
#          private bathroom       0.97      1.00      0.98     14554
#           shared bathroom       0.00      0.00      0.00       461
#                 undefined       0.00      0.00      0.00        11
#
#                  accuracy                           0.97     15029
#                 macro avg       0.24      0.25      0.25     15029
#              weighted avg       0.94      0.97      0.95     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting bedding
# F1 score: 0.15254795422738127
#                        precision    recall  f1-score   support
#
#              bunk bed       0.00      0.00      0.00        58
# double/double-or-twin       0.62      1.00      0.76      9265
#              multiple       0.00      0.00      0.00       145
#            single bed       0.00      0.00      0.00       219
#             undefined       0.00      0.00      0.00      5342
#
#              accuracy                           0.62     15029
#             macro avg       0.12      0.20      0.15     15029
#          weighted avg       0.38      0.62      0.47     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting capacity
# F1 score: 0.10902827987138566
#               precision    recall  f1-score   support
#
#       double       0.62      1.00      0.76      9274
#    quadruple       0.00      0.00      0.00       582
#    quintuple       0.00      0.00      0.00         3
#     sextuple       0.00      0.00      0.00         2
#       single       0.00      0.00      0.00      1186
#       triple       0.00      0.00      0.00       373
#    undefined       0.00      0.00      0.00      3609
#
#     accuracy                           0.62     15029
#    macro avg       0.09      0.14      0.11     15029
# weighted avg       0.38      0.62      0.47     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting club
# F1 score: 0.4984481895544802
#               precision    recall  f1-score   support
#
#         club       0.00      0.00      0.00        93
#     not club       0.99      1.00      1.00     14936
#
#     accuracy                           0.99     15029
#    macro avg       0.50      0.50      0.50     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting balcony
# F1 score: 0.48594198932822547
#               precision    recall  f1-score   support
#
#      balcony       0.00      0.00      0.00       822
#   no balcony       0.95      1.00      0.97     14207
#
#     accuracy                           0.95     15029
#    macro avg       0.47      0.50      0.49     15029
# weighted avg       0.89      0.95      0.92     15029
#
# Metrics report for DummyClassifier(random_state=42, strategy='most_frequent') predicting view
# F1 score: 0.02593321267641697
#                     precision    recall  f1-score   support
#
#           bay view       0.00      0.00      0.00        36
#         beachfront       0.00      0.00      0.00        25
#     bosphorus view       0.00      0.00      0.00        13
#  burj-khalifa view       0.00      0.00      0.00        10
#         canal view       0.00      0.00      0.00        23
#          city view       0.00      0.00      0.00       633
#     courtyard view       0.00      0.00      0.00        56
#  dubai-marina view       0.00      0.00      0.00         2
#        garden view       0.00      0.00      0.00       382
#          golf view       0.00      0.00      0.00         6
#       harbour view       0.00      0.00      0.00        52
#        inland view       0.00      0.00      0.00        22
#       kremlin view       0.00      0.00      0.00         3
#          lake view       0.00      0.00      0.00        67
#          land view       0.00      0.00      0.00        75
#      mountain view       0.00      0.00      0.00       107
#        ocean front       0.00      0.00      0.00        36
#         ocean view       0.00      0.00      0.00       132
#     panoramic view       0.00      0.00      0.00        14
#          park view       0.00      0.00      0.00        47
#       partial view       0.00      0.00      0.00        17
# partial-ocean view       0.00      0.00      0.00        22
#   partial-sea view       0.00      0.00      0.00       161
#          pool view       0.00      0.00      0.00       196
#         river view       0.00      0.00      0.00        78
#          sea front       0.00      0.00      0.00        18
#           sea view       0.00      0.00      0.00       721
#  sheikh-zayed view       0.00      0.00      0.00         2
#        street view       0.00      0.00      0.00        20
#       sunrise view       0.00      0.00      0.00         3
#        sunset view       0.00      0.00      0.00        12
#          undefined       0.79      1.00      0.88     11850
#         water view       0.00      0.00      0.00        41
#          with view       0.00      0.00      0.00       147
#
#           accuracy                           0.79     15029
#          macro avg       0.02      0.03      0.03     15029
#       weighted avg       0.62      0.79      0.70     15029
#
#
# ----------------------------------------
# Metrics report for ComplementNB() predicting class
# F1 score: 0.8012510295540025
#               precision    recall  f1-score   support
#
#    apartment       0.76      0.97      0.85       661
#     bungalow       0.89      0.99      0.94        68
#      camping       0.08      1.00      0.15         3
#      capsule       0.81      0.79      0.80        28
#       chalet       0.95      1.00      0.97        19
#      cottage       0.73      0.93      0.82        58
#         dorm       0.63      1.00      0.77       262
# junior-suite       0.87      0.98      0.92       399
#         room       0.99      0.92      0.95     11479
# run-of-house       0.69      0.82      0.75        11
#       studio       0.77      0.94      0.85       584
#        suite       0.76      0.83      0.79      1255
#         tent       0.71      1.00      0.83        10
#        villa       0.69      1.00      0.82       192
#
#     accuracy                           0.92     15029
#    macro avg       0.74      0.94      0.80     15029
# weighted avg       0.94      0.92      0.92     15029
#
# Metrics report for ComplementNB() predicting quality
# F1 score: 0.8850782805412704
#               precision    recall  f1-score   support
#
#   ambassador       0.15      1.00      0.27         4
#     business       0.83      0.80      0.81       127
#      classic       0.95      0.99      0.97       535
#      comfort       0.92      0.97      0.95       439
#       deluxe       0.83      0.96      0.89      1869
#      economy       0.94      0.91      0.93       438
#    executive       0.90      0.99      0.94       310
#        grand       0.93      0.75      0.83        73
#       luxury       0.93      0.98      0.95       127
#     platinum       0.80      1.00      0.89         4
#      premier       0.90      0.99      0.94       141
#      premium       0.91      0.93      0.92       346
# presidential       0.95      1.00      0.97        18
#     prestige       0.90      1.00      0.95        28
#    privilege       0.94      0.91      0.93        35
#        royal       0.91      0.94      0.92        31
#     standard       0.96      0.86      0.91      6442
#     superior       0.96      0.96      0.96      1609
#    undefined       0.84      0.93      0.89      2453
#
#     accuracy                           0.91     15029
#    macro avg       0.87      0.94      0.89     15029
# weighted avg       0.92      0.91      0.91     15029
#
# Metrics report for ComplementNB() predicting bathroom
# F1 score: 0.5317971338078797
#                            precision    recall  f1-score   support
#
# external private bathroom       0.01      1.00      0.01         3
#          private bathroom       1.00      0.94      0.97     14554
#           shared bathroom       0.60      0.99      0.75       461
#                 undefined       0.25      1.00      0.40        11
#
#                  accuracy                           0.94     15029
#                 macro avg       0.46      0.98      0.53     15029
#              weighted avg       0.99      0.94      0.96     15029
#
# Metrics report for ComplementNB() predicting bedding
# F1 score: 0.3778396314705927
#                        precision    recall  f1-score   support
#
#              bunk bed       0.12      0.36      0.18        58
# double/double-or-twin       0.81      0.83      0.82      9265
#              multiple       0.00      0.00      0.00       145
#            single bed       0.20      0.22      0.21       219
#             undefined       0.70      0.67      0.68      5342
#
#              accuracy                           0.75     15029
#             macro avg       0.36      0.42      0.38     15029
#          weighted avg       0.75      0.75      0.75     15029
#
# Metrics report for ComplementNB() predicting capacity
# F1 score: 0.5948650530093111
#               precision    recall  f1-score   support
#
#       double       0.85      0.80      0.82      9274
#    quadruple       0.60      0.37      0.46       582
#    quintuple       0.50      1.00      0.67         3
#     sextuple       0.08      1.00      0.15         2
#       single       0.61      0.80      0.69      1186
#       triple       0.65      0.75      0.70       373
#    undefined       0.66      0.71      0.68      3609
#
#     accuracy                           0.76     15029
#    macro avg       0.56      0.77      0.59     15029
# weighted avg       0.77      0.76      0.76     15029
#
# Metrics report for ComplementNB() predicting club
# F1 score: 0.545360139551316
#               precision    recall  f1-score   support
#
#         club       0.07      0.87      0.13        93
#     not club       1.00      0.93      0.96     14936
#
#     accuracy                           0.93     15029
#    macro avg       0.53      0.90      0.55     15029
# weighted avg       0.99      0.93      0.96     15029
#
# Metrics report for ComplementNB() predicting balcony
# F1 score: 0.7083073762343429
#               precision    recall  f1-score   support
#
#      balcony       0.32      0.97      0.48       822
#   no balcony       1.00      0.88      0.94     14207
#
#     accuracy                           0.89     15029
#    macro avg       0.66      0.93      0.71     15029
# weighted avg       0.96      0.89      0.91     15029
#
# Metrics report for ComplementNB() predicting view
# F1 score: 0.6494053709190506
#                     precision    recall  f1-score   support
#
#           bay view       0.41      0.92      0.56        36
#         beachfront       0.64      0.84      0.72        25
#     bosphorus view       0.54      1.00      0.70        13
#  burj-khalifa view       0.50      1.00      0.67        10
#         canal view       0.73      0.96      0.83        23
#          city view       0.76      0.95      0.84       633
#     courtyard view       0.68      0.82      0.74        56
#  dubai-marina view       0.00      0.00      0.00         2
#        garden view       0.73      0.96      0.83       382
#          golf view       0.38      1.00      0.55         6
#       harbour view       0.74      0.98      0.84        52
#        inland view       0.88      1.00      0.94        22
#       kremlin view       0.04      1.00      0.08         3
#          lake view       0.81      0.93      0.86        67
#          land view       0.82      0.93      0.88        75
#      mountain view       0.83      0.96      0.89       107
#        ocean front       0.66      0.58      0.62        36
#         ocean view       0.57      0.95      0.71       132
#     panoramic view       0.40      0.86      0.55        14
#          park view       0.66      0.87      0.75        47
#       partial view       0.14      0.12      0.13        17
# partial-ocean view       0.00      0.00      0.00        22
#   partial-sea view       0.77      0.57      0.66       161
#          pool view       0.54      0.86      0.67       196
#         river view       0.75      0.99      0.85        78
#          sea front       0.62      0.44      0.52        18
#           sea view       0.64      0.94      0.76       721
#  sheikh-zayed view       0.11      1.00      0.19         2
#        street view       0.65      0.85      0.74        20
#       sunrise view       0.75      1.00      0.86         3
#        sunset view       0.71      1.00      0.83        12
#          undefined       0.99      0.89      0.94     11850
#         water view       0.70      0.98      0.82        41
#          with view       0.56      0.58      0.57       147
#
#           accuracy                           0.89     15029
#          macro avg       0.58      0.82      0.65     15029
#       weighted avg       0.92      0.89      0.90     15029
#
#
# ----------------------------------------
# Metrics report for RidgeClassifier() predicting class
# F1 score: 0.9699198131152933
#               precision    recall  f1-score   support
#
#    apartment       0.97      0.97      0.97       661
#     bungalow       0.99      0.97      0.98        68
#      camping       1.00      1.00      1.00         3
#      capsule       1.00      0.96      0.98        28
#       chalet       1.00      0.89      0.94        19
#      cottage       0.90      0.91      0.91        58
#         dorm       1.00      0.94      0.97       262
# junior-suite       0.94      0.97      0.96       399
#         room       0.99      1.00      0.99     11479
# run-of-house       1.00      0.91      0.95        11
#       studio       0.99      0.94      0.96       584
#        suite       1.00      0.96      0.98      1255
#         tent       1.00      1.00      1.00        10
#        villa       0.99      0.98      0.99       192
#
#     accuracy                           0.99     15029
#    macro avg       0.98      0.96      0.97     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for RidgeClassifier() predicting quality
# F1 score: 0.9410095761288219
#               precision    recall  f1-score   support
#
#   ambassador       0.80      1.00      0.89         4
#     business       0.90      0.94      0.92       127
#      classic       0.98      0.98      0.98       535
#      comfort       0.95      0.97      0.96       439
#       deluxe       0.97      0.95      0.96      1869
#      economy       0.99      0.90      0.94       438
#    executive       0.93      0.97      0.95       310
#        grand       0.93      0.73      0.82        73
#       luxury       0.98      0.97      0.98       127
#     platinum       1.00      1.00      1.00         4
#      premier       0.92      0.99      0.95       141
#      premium       0.93      0.94      0.94       346
# presidential       0.95      1.00      0.97        18
#     prestige       0.90      1.00      0.95        28
#    privilege       0.94      0.91      0.93        35
#        royal       0.85      0.94      0.89        31
#     standard       0.95      0.97      0.96      6442
#     superior       0.99      0.95      0.97      1609
#    undefined       0.93      0.92      0.93      2453
#
#     accuracy                           0.95     15029
#    macro avg       0.94      0.95      0.94     15029
# weighted avg       0.95      0.95      0.95     15029
#
# Metrics report for RidgeClassifier() predicting bathroom
# F1 score: 0.9100974671175958
#                            precision    recall  f1-score   support
#
# external private bathroom       1.00      0.67      0.80         3
#          private bathroom       1.00      1.00      1.00     14554
#           shared bathroom       0.99      0.90      0.94       461
#                 undefined       1.00      0.82      0.90        11
#
#                  accuracy                           1.00     15029
#                 macro avg       1.00      0.85      0.91     15029
#              weighted avg       1.00      1.00      1.00     15029
#
# Metrics report for RidgeClassifier() predicting bedding
# F1 score: 0.5147788936590109
#                        precision    recall  f1-score   support
#
#              bunk bed       0.83      0.66      0.73        58
# double/double-or-twin       0.86      0.93      0.89      9265
#              multiple       0.00      0.00      0.00       145
#            single bed       0.64      0.07      0.13       219
#             undefined       0.85      0.79      0.82      5342
#
#              accuracy                           0.86     15029
#             macro avg       0.63      0.49      0.51     15029
#          weighted avg       0.85      0.86      0.85     15029
#
# Metrics report for RidgeClassifier() predicting capacity
# F1 score: 0.8257247768345986
#               precision    recall  f1-score   support
#
#       double       0.87      0.94      0.91      9274
#    quadruple       0.91      0.32      0.48       582
#    quintuple       1.00      1.00      1.00         3
#     sextuple       1.00      1.00      1.00         2
#       single       0.77      0.76      0.76      1186
#       triple       0.86      0.71      0.78       373
#    undefined       0.89      0.82      0.86      3609
#
#     accuracy                           0.87     15029
#    macro avg       0.90      0.79      0.83     15029
# weighted avg       0.87      0.87      0.86     15029
#
# Metrics report for RidgeClassifier() predicting club
# F1 score: 0.8287918978406577
#               precision    recall  f1-score   support
#
#         club       0.63      0.69      0.66        93
#     not club       1.00      1.00      1.00     14936
#
#     accuracy                           1.00     15029
#    macro avg       0.82      0.84      0.83     15029
# weighted avg       1.00      1.00      1.00     15029
#
# Metrics report for RidgeClassifier() predicting balcony
# F1 score: 0.9617490393924049
#               precision    recall  f1-score   support
#
#      balcony       0.91      0.95      0.93       822
#   no balcony       1.00      0.99      1.00     14207
#
#     accuracy                           0.99     15029
#    macro avg       0.95      0.97      0.96     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for RidgeClassifier() predicting view
# F1 score: 0.7951373009146154
#                     precision    recall  f1-score   support
#
#           bay view       0.87      0.92      0.89        36
#         beachfront       0.95      0.72      0.82        25
#     bosphorus view       0.72      1.00      0.84        13
#  burj-khalifa view       1.00      1.00      1.00        10
#         canal view       0.82      1.00      0.90        23
#          city view       0.92      0.96      0.94       633
#     courtyard view       0.87      0.84      0.85        56
#  dubai-marina view       0.00      0.00      0.00         2
#        garden view       0.90      0.97      0.93       382
#          golf view       0.75      1.00      0.86         6
#       harbour view       0.80      0.98      0.88        52
#        inland view       0.88      1.00      0.94        22
#       kremlin view       0.75      1.00      0.86         3
#          lake view       0.89      0.94      0.91        67
#          land view       0.87      0.88      0.87        75
#      mountain view       0.92      0.95      0.94       107
#        ocean front       0.91      0.58      0.71        36
#         ocean view       0.78      0.94      0.86       132
#     panoramic view       0.90      0.64      0.75        14
#          park view       0.84      0.87      0.85        47
#       partial view       0.50      0.06      0.11        17
# partial-ocean view       0.00      0.00      0.00        22
#   partial-sea view       0.81      0.61      0.70       161
#          pool view       0.97      0.86      0.91       196
#         river view       0.89      0.96      0.93        78
#          sea front       0.89      0.44      0.59        18
#           sea view       0.88      0.97      0.92       721
#  sheikh-zayed view       1.00      1.00      1.00         2
#        street view       0.83      1.00      0.91        20
#       sunrise view       0.75      1.00      0.86         3
#        sunset view       1.00      0.92      0.96        12
#          undefined       0.99      0.98      0.98     11850
#         water view       0.90      0.93      0.92        41
#          with view       0.80      0.55      0.65       147
#
#           accuracy                           0.96     15029
#          macro avg       0.81      0.81      0.80     15029
#       weighted avg       0.96      0.96      0.96     15029
#
#
# ----------------------------------------
# Metrics report for LinearSVC() predicting class
# F1 score: 0.9865702739854945
#               precision    recall  f1-score   support
#
#    apartment       1.00      1.00      1.00       661
#     bungalow       1.00      0.97      0.99        68
#      camping       1.00      1.00      1.00         3
#      capsule       1.00      0.96      0.98        28
#       chalet       1.00      0.95      0.97        19
#      cottage       1.00      0.93      0.96        58
#         dorm       1.00      0.97      0.98       262
# junior-suite       0.98      0.98      0.98       399
#         room       1.00      1.00      1.00     11479
# run-of-house       1.00      0.91      0.95        11
#       studio       1.00      1.00      1.00       584
#        suite       1.00      0.99      0.99      1255
#         tent       1.00      1.00      1.00        10
#        villa       1.00      1.00      1.00       192
#
#     accuracy                           1.00     15029
#    macro avg       1.00      0.98      0.99     15029
# weighted avg       1.00      1.00      1.00     15029
#
# Metrics report for LinearSVC() predicting quality
# F1 score: 0.9808960388983696
#               precision    recall  f1-score   support
#
#   ambassador       1.00      1.00      1.00         4
#     business       0.98      0.97      0.97       127
#      classic       1.00      0.99      1.00       535
#      comfort       0.98      0.98      0.98       439
#       deluxe       0.98      0.99      0.99      1869
#      economy       0.98      0.92      0.95       438
#    executive       0.97      0.99      0.98       310
#        grand       1.00      0.96      0.98        73
#       luxury       0.99      1.00      1.00       127
#     platinum       1.00      1.00      1.00         4
#      premier       0.99      0.99      0.99       141
#      premium       1.00      0.99      0.99       346
# presidential       0.95      1.00      0.97        18
#     prestige       0.93      1.00      0.97        28
#    privilege       0.94      0.91      0.93        35
#        royal       1.00      0.97      0.98        31
#     standard       0.99      0.99      0.99      6442
#     superior       0.99      0.99      0.99      1609
#    undefined       0.99      0.98      0.98      2453
#
#     accuracy                           0.99     15029
#    macro avg       0.98      0.98      0.98     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for LinearSVC() predicting bathroom
# F1 score: 0.9926339285714286
#                            precision    recall  f1-score   support
#
# external private bathroom       1.00      1.00      1.00         3
#          private bathroom       1.00      1.00      1.00     14554
#           shared bathroom       0.98      0.96      0.97       461
#                 undefined       1.00      1.00      1.00        11
#
#                  accuracy                           1.00     15029
#                 macro avg       1.00      0.99      0.99     15029
#              weighted avg       1.00      1.00      1.00     15029
#
# Metrics report for LinearSVC() predicting bedding
# F1 score: 0.6348930936462058
#                        precision    recall  f1-score   support
#
#              bunk bed       0.85      0.88      0.86        58
# double/double-or-twin       0.89      0.94      0.91      9265
#              multiple       0.71      0.03      0.07       145
#            single bed       0.73      0.36      0.48       219
#             undefined       0.88      0.83      0.85      5342
#
#              accuracy                           0.88     15029
#             macro avg       0.81      0.61      0.63     15029
#          weighted avg       0.88      0.88      0.88     15029
#
# Metrics report for LinearSVC() predicting capacity
# F1 score: 0.8875132056023026
#               precision    recall  f1-score   support
#
#       double       0.92      0.96      0.94      9274
#    quadruple       0.87      0.64      0.74       582
#    quintuple       1.00      1.00      1.00         3
#     sextuple       1.00      1.00      1.00         2
#       single       0.84      0.77      0.81      1186
#       triple       0.80      0.83      0.81       373
#    undefined       0.94      0.90      0.92      3609
#
#     accuracy                           0.91     15029
#    macro avg       0.91      0.87      0.89     15029
# weighted avg       0.91      0.91      0.91     15029
#
# Metrics report for LinearSVC() predicting club
# F1 score: 0.8921539079766928
#               precision    recall  f1-score   support
#
#         club       0.75      0.83      0.79        93
#     not club       1.00      1.00      1.00     14936
#
#     accuracy                           1.00     15029
#    macro avg       0.87      0.91      0.89     15029
# weighted avg       1.00      1.00      1.00     15029
#
# Metrics report for LinearSVC() predicting balcony
# F1 score: 0.9752407311307156
#               precision    recall  f1-score   support
#
#      balcony       0.95      0.95      0.95       822
#   no balcony       1.00      1.00      1.00     14207
#
#     accuracy                           0.99     15029
#    macro avg       0.97      0.98      0.98     15029
# weighted avg       0.99      0.99      0.99     15029
#
# Metrics report for LinearSVC() predicting view
# F1 score: 0.9016073396855188
#                     precision    recall  f1-score   support
#
#           bay view       0.90      0.97      0.93        36
#         beachfront       0.90      0.76      0.83        25
#     bosphorus view       0.93      1.00      0.96        13
#  burj-khalifa view       1.00      1.00      1.00        10
#         canal view       0.88      1.00      0.94        23
#          city view       0.97      0.97      0.97       633
#     courtyard view       1.00      0.89      0.94        56
#  dubai-marina view       1.00      1.00      1.00         2
#        garden view       0.94      0.95      0.94       382
#          golf view       0.75      1.00      0.86         6
#       harbour view       0.89      0.96      0.93        52
#        inland view       0.95      0.95      0.95        22
#       kremlin view       0.75      1.00      0.86         3
#          lake view       0.97      0.97      0.97        67
#          land view       0.91      0.91      0.91        75
#      mountain view       0.94      0.94      0.94       107
#        ocean front       0.89      0.67      0.76        36
#         ocean view       0.86      0.94      0.90       132
#     panoramic view       0.91      0.71      0.80        14
#          park view       0.98      0.87      0.92        47
#       partial view       0.92      0.65      0.76        17
# partial-ocean view       1.00      0.95      0.98        22
#   partial-sea view       0.98      0.63      0.77       161
#          pool view       0.98      0.91      0.94       196
#         river view       0.91      0.96      0.94        78
#          sea front       0.89      0.44      0.59        18
#           sea view       0.89      0.98      0.93       721
#  sheikh-zayed view       1.00      1.00      1.00         2
#        street view       0.95      0.90      0.92        20
#       sunrise view       0.75      1.00      0.86         3
#        sunset view       1.00      1.00      1.00        12
#          undefined       0.99      0.99      0.99     11850
#         water view       0.95      1.00      0.98        41
#          with view       0.73      0.65      0.69       147
#
#           accuracy                           0.97     15029
#          macro avg       0.92      0.90      0.90     15029
#       weighted avg       0.97      0.97      0.97     15029
#           DummyClassifier(random_state=42, strategy='stratified')  \
# class                                              0.071641
# quality                                            0.050188
# bathroom                                           0.251805
# bedding                                            0.198741
# capacity                                           0.141057
#
#           DummyClassifier(random_state=42, strategy='most_frequent')  \
# class                                              0.061863
# quality                                            0.031582
# bathroom                                           0.245986
# bedding                                            0.152548
# capacity                                           0.109028
#
#           ComplementNB()  RidgeClassifier()  LinearSVC()
# class           0.801251           0.969920     0.986570
# quality         0.885078           0.941010     0.980896
# bathroom        0.531797           0.910097     0.992634
# bedding         0.377840           0.514779     0.634893
# capacity        0.594865           0.825725     0.887513

# %% [markdown]
# Сохраним две лучшие модели для дальнейших экспериментов:

# %%
import joblib
from tqdm import tqdm

MODELS_DIR = Path("../models")

for target_name in tqdm(target_names):
    X_train, X_test, y_train, y_test = split_data(df, target_name)
    ridge_pipe = train_classifier(get_linear_classifier(), X_train, y_train)
    joblib.dump(ridge_pipe, MODELS_DIR / f"ridge_pipeline_{target_name}.pkl")
    
    svc_pipe = train_classifier(get_linear_svc_classifier(), X_train, y_train)
    joblib.dump(svc_pipe, MODELS_DIR / f"svc_pipeline_{target_name}.pkl")
# Out:
# 100%|██████████| 8/8 [00:29<00:00,  3.74s/it]
